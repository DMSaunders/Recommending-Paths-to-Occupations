# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys 
from pandas.tools.plotting import scatter_matrix
import scipy.stats as scs

import sys
sys.path.append('../')
import src.features.feature_cleaning as feature_cleaning

# %%
df, fieldofdegree_df, SOCP_labels, schl_labels, major_major, NAICSP_labels_df = feature_cleaning.load_dfs()

# %%
youngemp_df = feature_cleaning.clean_that_target(df, SOCP_labels)
# Out:
# ../src/features/feature_cleaning.py:79: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SOCPdf = df.dropna(axis='index', subset=['SOCP'])[df.SOCP != '999920']
# Number of employed people: 218454
# Percent employed people: 0.5785711448056677
# Number of young employed people: 77406
# Percent young employed people(out of all PUMS): 0.20500827650135733
# Number of emp cats: 23

# %%
NAICSP_SOCP_df = feature_cleaning.create_NAICSP_SOCP_df(youngemp_df, NAICSP_labels_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77406 entries, 0 to 77405
# Data columns (total 7 columns):
# SERIALNO           77406 non-null int64
# SOCP               77406 non-null object
# MAJ_SOCP           77406 non-null object
# MAJ_SOCP_labels    77406 non-null object
# NAICSP             77406 non-null object
# NAICSP_labels      77406 non-null object
# MAJ_NAICSP         77399 non-null object
# dtypes: int64(1), object(6)
# memory usage: 32.8 MB
# None

# %%
NAICSP_SOCP_df.sample(20)
# Out:
#             SERIALNO    SOCP MAJ_SOCP                         MAJ_SOCP_labels   NAICSP                                      NAICSP_labels MAJ_NAICSP
# 15098  2017000286996  499021       49   Installation, Maintenance, and Repair       23  CON-Construction, (The Cleaning Of Buildings A...        CON
# 50184  2017000959105  537064       53      Transportation and Material Moving    3118Z  MFG-Bakeries And Tortilla, Except Retail Bakeries        MFG
# 48784  2017000932670  252020       25        Education, Training, and Library     6111               EDU-Elementary And Secondary Schools        EDU
# 21303  2017000407607  435030       43       Office and Administrative Support      492                        TRN-Couriers And Messengers        TRN
# 43205  2017000824523  399021       39               Personal Care and Service     6241                 SCA-Individual And Family Services        SCA
# ...

# %%
NAICSP_SOCP_df.info()

# %%
NAICSP_SOCP_df.info()
